# %% [markdown]
# ## NYC Taxi Data Experimnt Tracking

# %%
# !python -V
# Out:
# Python 3.11.8

# %%
import requests
import pickle

import pandas as pd

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.svm import LinearSVR

from tqdm import tqdm

# %%
! pwd
# Out:
# /Users/emelidral/Dev/hs-2024-industrial-ml

# %%
# !mkdir data

# %%
# %%bash
# ls
# Out:
# README.md
# data
# experiment_tracking.ipynb
# requirements.txt

# %%
files = [('green_tripdata_2023-02.parquet', './data'), ('green_tripdata_2023-01.parquet', './data')]

print("Download files:")
for file, path in files:
    url=f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
    resp=requests.get(url, stream=True)
    save_path=f"{path}/{file}"
    with open(save_path, "wb") as handle:
        for data in tqdm(resp.iter_content(),
                        desc=f"{file}",
                        postfix=f"save to {save_path}",
                        total=int(resp.headers["Content-Length"])):
            handle.write(data)
# Out:
# Download files:
# green_tripdata_2023-02.parquet: 100%|█████████████| 1533740/1533740 [00:04<00:00, 367895.71it/s, save to ./data/green_tripdata_2023-02.parquet]
# green_tripdata_2023-01.parquet: 100%|█████████████| 1427002/1427002 [00:03<00:00, 390224.96it/s, save to ./data/green_tripdata_2023-01.parquet]

# %%
train_raw_data = pd.read_parquet('data/green_tripdata_2023-01.parquet')
val_raw_data = pd.read_parquet('data/green_tripdata_2023-02.parquet')

# %%
train_raw_data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
# 1         2  2023-01-01 00:51:03   2023-01-01 00:57:49                  N
# 2         2  2023-01-01 00:35:12   2023-01-01 00:41:32                  N
# 3         1  2023-01-01 00:13:14   2023-01-01 00:19:03                  N
# 4         1  2023-01-01 00:33:04   2023-01-01 00:39:02                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143              1.0           2.58
# 1         1.0            24            43              1.0           1.81
# 2         1.0           223           179              1.0           0.00
# 3         1.0            41           238              1.0           1.30
# 4         1.0            41            74              1.0           1.10
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0         14.9    1.0      0.5        4.03           0.0      None
# 1         10.7    1.0      0.5        2.64           0.0      None
# 2          7.2    1.0      0.5        1.94           0.0      None
# 3          6.5    0.5      1.5        1.70           0.0      None
# 4          6.0    0.5      1.5        0.00           0.0      None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
# 1                    1.0         15.84           1.0        1.0
# 2                    1.0         11.64           1.0        1.0
# 3                    1.0         10.20           1.0        1.0
# 4                    1.0          8.00           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %%
train_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68211 entries, 0 to 68210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               68211 non-null  int64
#  1   lpep_pickup_datetime   68211 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  68211 non-null  datetime64[us]
#  3   store_and_fwd_flag     63887 non-null  object
#  4   RatecodeID             63887 non-null  float64
#  5   PULocationID           68211 non-null  int64
#  6   DOLocationID           68211 non-null  int64
#  7   passenger_count        63887 non-null  float64
#  8   trip_distance          68211 non-null  float64
#  9   fare_amount            68211 non-null  float64
#  10  extra                  68211 non-null  float64
#  11  mta_tax                68211 non-null  float64
#  12  tip_amount             68211 non-null  float64
#  13  tolls_amount           68211 non-null  float64
#  14  ehail_fee              0 non-null      object
#  15  improvement_surcharge  68211 non-null  float64
#  16  total_amount           68211 non-null  float64
#  17  payment_type           63887 non-null  float64
#  18  trip_type              63877 non-null  float64
#  19  congestion_surcharge   63887 non-null  float64
# dtypes: datetime64[us](2), float64(13), int64(3), object(2)
# memory usage: 10.4+ MB

# %%
def process_dataframe(data):
    data.lpep_dropoff_datetime = pd.to_datetime(data.lpep_dropoff_datetime)
    data.lpep_pickup_datetime = pd.to_datetime(data.lpep_pickup_datetime)

    data['duration'] = data.lpep_dropoff_datetime - data.lpep_pickup_datetime
    data.duration = data.duration.apply(lambda td: td.total_seconds() / 60)
    data = data[(data.duration >= 1) & (data.duration <= 60)]
    
    data['PULocationID'].astype(str, copy=False)
    data['DOLocationID'].astype(str, copy=False)
    
    return data

# %%
num_features = ['trip_distance', 'extra', 'fare_amount']
cat_features = ['PULocationID', 'DOLocationID']

# %%
X_train = process_dataframe(train_raw_data)[num_features + cat_features]
X_val = process_dataframe(val_raw_data)[num_features + cat_features] 

y_train = process_dataframe(train_raw_data)['duration']
y_val = process_dataframe(val_raw_data)['duration']

# %%
X_train.isnull().sum()
# Out:
# trip_distance    0
# extra            0
# fare_amount      0
# PULocationID     0
# DOLocationID     0
# dtype: int64

# %% [markdown]
# ## Simple model

# %%
lr = Ridge()

lr.fit(X_train, y_train)

y_val_pred = lr.predict(X_val)
mean_squared_error(y_val, y_val_pred, squared=False)
# Out:
# 5.242476415412269

# %% [markdown]
# ## MLflow

# %%
import mlflow

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("test")
# Out:
# 2024/02/28 11:37:36 INFO mlflow.tracking.fluent: Experiment with name 'test' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/emelidral/Dev/hs-2024-industrial-ml/mlruns/1', creation_time=1709120256919, experiment_id='1', last_update_time=1709120256919, lifecycle_stage='active', name='test', tags={}>

# %%
with mlflow.start_run():
    mlflow.set_tag("workspace", "inclass")
    mlflow.log_param("train_data_path", "data/green_tripdata_2023-01.parquet")
    mlflow.log_param("vl_data_path", "data/green_tripdata_2023-02.parquet")

    alpha = 0.5
    mlflow.log_param("alpha", alpha)
    
    lr = Lasso(alpha)

    lr.fit(X_train, y_train)
    y_val_pred = lr.predict(X_val)
    
    rmse = mean_squared_error(y_val, y_val_pred, squared=False)

    mlflow.log_metric("rmse", rmse)

# %% [markdown]
# ## Hyperparameter Optimisation

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
val = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        num_rounds = 200
        early_stopping_rounds = 50

        mlflow.set_tag("workspace", "inclass")
        mlflow.set_tag("model", "xgb_fixed")
        mlflow.log_params(params)
        mlflow.log_param("train_data_path", "data/green_tripdata_2023-01.parquet")
        mlflow.log_param("vl_data_path", "data/green_tripdata_2023-02.parquet")

        booster = xgb.train(
            params=params,
            dtrain=train,
            evals=[(val, "validation")],
            num_boost_round=num_rounds,
            early_stopping_rounds=early_stopping_rounds
        )

        y_val_pred = booster.predict(val)
        rmse = mean_squared_error(y_val, y_val_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

        return {
        'loss': rmse,
        'status': STATUS_OK}

# %%
X_train.shape
# Out:
# (65946, 5)

# %%
grid_seach_params = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'max_leaves': scope.int(hp.quniform('max_leaves', 6, 10, 1)),
    'reg_lambda': hp.loguniform('reg_lambda', -5, -1),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'objective': 'reg:squarederror', #|y - y*|
    'seed':111,
}

# %%
best_model = fmin(
    fn=objective,
    space=grid_seach_params,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:7.41054
# [1]	validation-rmse:6.19673
# [2]	validation-rmse:5.48130
# [3]	validation-rmse:5.05621
# [4]	validation-rmse:4.79038
# [5]	validation-rmse:4.61307
# [6]	validation-rmse:4.50720
# [7]	validation-rmse:4.41681
# [8]	validation-rmse:4.35356
# [9]	validation-rmse:4.31441
# [10]	validation-rmse:4.27172
# [11]	validation-rmse:4.25724
# [12]	validation-rmse:4.24351
# [13]	validation-rmse:4.22917
# [14]	validation-rmse:4.21918
# [15]	validation-rmse:4.19047
# [16]	validation-rmse:4.16292
# [17]	validation-rmse:4.16019
# [18]	validation-rmse:4.14890
# [19]	validation-rmse:4.13134
# [20]	validation-rmse:4.11806
# [21]	validation-rmse:4.09896
# [22]	validation-rmse:4.09447
# [23]	validation-rmse:4.08457
# [24]	validation-rmse:4.07733
# [25]	validation-rmse:4.07222
# [26]	validation-rmse:4.06718
# [27]	validation-rmse:4.06630
# [28]	validation-rmse:4.06157
# [29]	validation-rmse:4.05575
# [30]	validation-rmse:4.05121
# [31]	validation-rmse:4.03891
# [32]	validation-rmse:4.03634
# [33]	validation-rmse:4.02493
# [34]	validation-rmse:4.02126
# [35]	validation-rmse:4.01729
# [36]	validation-rmse:4.01619
# [37]	validation-rmse:4.01437
# [38]	validation-rmse:4.01258
# [39]	validation-rmse:4.00926
# [40]	validation-rmse:4.00246
# [41]	validation-rmse:3.98792
# [42]	validation-rmse:3.98412
# [43]	validation-rmse:3.97413
# [44]	validation-rmse:3.96828
# [45]	validation-rmse:3.96916
# [46]	validation-rmse:3.97195
# [47]	validation-rmse:3.96496
# [48]	validation-rmse:3.95892
# [49]	validation-rmse:3.95335
# [50]	validation-rmse:3.94985
# [51]	validation-rmse:3.94832
# [52]	validation-rmse:3.93982
# [53]	validation-rmse:3.93281
# [54]	validation-rmse:3.92978
# [55]	validation-rmse:3.92121
# [56]	validation-rmse:3.91840
# [57]	validation-rmse:3.91748
# [58]	validation-rmse:3.90962
# [59]	validation-rmse:3.90957
# [60]	validation-rmse:3.90412
# [61]	validation-rmse:3.90238
# [62]	validation-rmse:3.90010
# [63]	validation-rmse:3.89800
# [64]	validation-rmse:3.89642
# [65]	validation-rmse:3.89134
# [66]	validation-rmse:3.89383
# [67]	validation-rmse:3.89335
# [68]	validation-rmse:3.89530
# [69]	validation-rmse:3.89407
# [70]	validation-rmse:3.89488
# [71]	validation-rmse:3.89508
# [72]	validation-rmse:3.89219
# [73]	validation-rmse:3.89109
# [74]	validation-rmse:3.88958
# [75]	validation-rmse:3.89080
# [76]	validation-rmse:3.88682
# [77]	validation-rmse:3.88507
# [78]	validation-rmse:3.88313
# [79]	validation-rmse:3.88250
# [80]	validation-rmse:3.87702
# [81]	validation-rmse:3.87347
# [82]	validation-rmse:3.87067
# [83]	validation-rmse:3.86800
# [84]	validation-rmse:3.86753
# [85]	validation-rmse:3.86760
# [86]	validation-rmse:3.86565
# [87]	validation-rmse:3.86721
# [88]	validation-rmse:3.86094
# [89]	validation-rmse:3.85552
# [90]	validation-rmse:3.85398
# [91]	validation-rmse:3.85031
# [92]	validation-rmse:3.85001
# [93]	validation-rmse:3.84814
# [94]	validation-rmse:3.84662
# [95]	validation-rmse:3.84184
# [96]	validation-rmse:3.84230
# [97]	validation-rmse:3.83672
# [98]	validation-rmse:3.83586
# [99]	validation-rmse:3.83503
# [100]	validation-rmse:3.83545
# [101]	validation-rmse:3.83471
# [102]	validation-rmse:3.83385
# [103]	validation-rmse:3.83198
# [104]	validation-rmse:3.83191
# [105]	validation-rmse:3.82306
# [106]	validation-rmse:3.82219
# [107]	validation-rmse:3.82105
# [108]	validation-rmse:3.82047
# [109]	validation-rmse:3.81447
# [110]	validation-rmse:3.81206
# [111]	validation-rmse:3.81200
# [112]	validation-rmse:3.81151
# [113]	validation-rmse:3.81245
# [114]	validation-rmse:3.81308
# [115]	validation-rmse:3.81189
# [116]	validation-rmse:3.81020
# [117]	validation-rmse:3.80891
# [118]	validation-rmse:3.80756
# [119]	validation-rmse:3.80730
# [120]	validation-rmse:3.80526
# [121]	validation-rmse:3.80465
# [122]	validation-rmse:3.80432
# [123]	validation-rmse:3.80394
# [124]	validation-rmse:3.80363
# [125]	validation-rmse:3.80355
# [126]	validation-rmse:3.80098
# [127]	validation-rmse:3.80085
# [128]	validation-rmse:3.80151
# [129]	validation-rmse:3.80062
# [130]	validation-rmse:3.80118
# [131]	validation-rmse:3.80146
# [132]	validation-rmse:3.79810
# [133]	validation-rmse:3.79896
# [134]	validation-rmse:3.79851
# [135]	validation-rmse:3.79803
# [136]	validation-rmse:3.79507
# [137]	validation-rmse:3.79524
# [138]	validation-rmse:3.79066
# [139]	validation-rmse:3.78756
# [140]	validation-rmse:3.78746
# [141]	validation-rmse:3.78808
# [142]	validation-rmse:3.78732
# [143]	validation-rmse:3.78789
# [144]	validation-rmse:3.78606
# [145]	validation-rmse:3.78402
# [146]	validation-rmse:3.78465
# [147]	validation-rmse:3.78446
# [148]	validation-rmse:3.78278
# [149]	validation-rmse:3.78167
# [150]	validation-rmse:3.78107
# [151]	validation-rmse:3.78033
# [152]	validation-rmse:3.77754
# [153]	validation-rmse:3.77639
# [154]	validation-rmse:3.77482
# [155]	validation-rmse:3.77444
# [156]	validation-rmse:3.77485
# [157]	validation-rmse:3.77267
# [158]	validation-rmse:3.77303
# [159]	validation-rmse:3.77222
# [160]	validation-rmse:3.76750
# [161]	validation-rmse:3.76627
# [162]	validation-rmse:3.76557
# [163]	validation-rmse:3.76546
# [164]	validation-rmse:3.76547
# [165]	validation-rmse:3.76403
# [166]	validation-rmse:3.76519
# [167]	validation-rmse:3.76668
# [168]	validation-rmse:3.76703
# [169]	validation-rmse:3.76634
# [170]	validation-rmse:3.76391
# [171]	validation-rmse:3.76285
# [172]	validation-rmse:3.76015
# [173]	validation-rmse:3.76052
# [174]	validation-rmse:3.76041
# [175]	validation-rmse:3.75442
# [176]	validation-rmse:3.75053
# [177]	validation-rmse:3.74923
# [178]	validation-rmse:3.74667
# [179]	validation-rmse:3.74500
# [180]	validation-rmse:3.74497
# [181]	validation-rmse:3.74350
# [182]	validation-rmse:3.74240
# [183]	validation-rmse:3.74233
# [184]	validation-rmse:3.74243
# [185]	validation-rmse:3.74142
# [186]	validation-rmse:3.74074
# [187]	validation-rmse:3.73839
# [188]	validation-rmse:3.73743
# [189]	validation-rmse:3.73821
# [190]	validation-rmse:3.73765
# [191]	validation-rmse:3.73763
# [192]	validation-rmse:3.73694
# [193]	validation-rmse:3.73462
# [194]	validation-rmse:3.73325
# [195]	validation-rmse:3.73287
# [196]	validation-rmse:3.73207
# [197]	validation-rmse:3.73066
# [198]	validation-rmse:3.73039
# [199]	validation-rmse:3.72926
# [0]	validation-rmse:7.37566
# [1]	validation-rmse:6.15696
# [2]	validation-rmse:5.43224
# [3]	validation-rmse:5.01169
# [4]	validation-rmse:4.75519
# [5]	validation-rmse:4.57917
# [6]	validation-rmse:4.48604
# [7]	validation-rmse:4.40025
# [8]	validation-rmse:4.35565
# [9]	validation-rmse:4.29587
# [10]	validation-rmse:4.24422
# [11]	validation-rmse:4.20721
# [12]	validation-rmse:4.19787
# [13]	validation-rmse:4.17774
# [14]	validation-rmse:4.17176
# [15]	validation-rmse:4.16419
# [16]	validation-rmse:4.13701
# [17]	validation-rmse:4.12831
# [18]	validation-rmse:4.11851
# [19]	validation-rmse:4.10622
# [20]	validation-rmse:4.10045
# [21]	validation-rmse:4.08526
# [22]	validation-rmse:4.08311
# [23]	validation-rmse:4.06734
# [24]	validation-rmse:4.06808
# [25]	validation-rmse:4.05495
# [26]	validation-rmse:4.04691
# [27]	validation-rmse:4.04480
# [28]	validation-rmse:4.04266
# [29]	validation-rmse:4.04025
# [30]	validation-rmse:4.03002
# [31]	validation-rmse:4.02176
# [32]	validation-rmse:4.02013
# [33]	validation-rmse:4.00660
# [34]	validation-rmse:3.99878
# [35]	validation-rmse:3.99841
# [36]	validation-rmse:3.99408
# [37]	validation-rmse:3.99116
# [38]	validation-rmse:3.98854
# [39]	validation-rmse:3.98112
# [40]	validation-rmse:3.97221
# [41]	validation-rmse:3.96708
# [42]	validation-rmse:3.96563
# [43]	validation-rmse:3.96483
# [44]	validation-rmse:3.96404
# [45]	validation-rmse:3.95702
# [46]	validation-rmse:3.94247
# [47]	validation-rmse:3.94222
# [48]	validation-rmse:3.93911
# [49]	validation-rmse:3.92935
# [50]	validation-rmse:3.92210
# [51]	validation-rmse:3.91736
# [52]	validation-rmse:3.91686
# [53]	validation-rmse:3.91762
# [54]	validation-rmse:3.91497
# [55]	validation-rmse:3.91417
# [56]	validation-rmse:3.91019
# [57]	validation-rmse:3.90487
# [58]	validation-rmse:3.90855
# [59]	validation-rmse:3.90636
# [60]	validation-rmse:3.90088
# [61]	validation-rmse:3.89252
# [62]	validation-rmse:3.89355
# [63]	validation-rmse:3.88719
# [64]	validation-rmse:3.88156
# [65]	validation-rmse:3.87942
# [66]	validation-rmse:3.87931
# [67]	validation-rmse:3.87497
# [68]	validation-rmse:3.86420
# [69]	validation-rmse:3.86306
# [70]	validation-rmse:3.86032
# [71]	validation-rmse:3.85734
# [72]	validation-rmse:3.85070
# [73]	validation-rmse:3.85227
# [74]	validation-rmse:3.85023
# [75]	validation-rmse:3.84868
# [76]	validation-rmse:3.84852
# [77]	validation-rmse:3.84789
# [78]	validation-rmse:3.84355
# [79]	validation-rmse:3.84128
# [80]	validation-rmse:3.84117
# [81]	validation-rmse:3.84030
# [82]	validation-rmse:3.84082
# [83]	validation-rmse:3.83968
# [84]	validation-rmse:3.84122
# [85]	validation-rmse:3.83764
# [86]	validation-rmse:3.83583
# [87]	validation-rmse:3.83511
# [88]	validation-rmse:3.83419
# [89]	validation-rmse:3.82802
# [90]	validation-rmse:3.82715
# [91]	validation-rmse:3.82580
# [92]	validation-rmse:3.82403
# [93]	validation-rmse:3.82372
# [94]	validation-rmse:3.82331
# [95]	validation-rmse:3.81815
# [96]	validation-rmse:3.81739
# [97]	validation-rmse:3.81489
# [98]	validation-rmse:3.81526
# [99]	validation-rmse:3.81503
# [100]	validation-rmse:3.81485
# [101]	validation-rmse:3.81287
# [102]	validation-rmse:3.80995
# [103]	validation-rmse:3.80717
# [104]	validation-rmse:3.80726
# [105]	validation-rmse:3.80296
# [106]	validation-rmse:3.79784
# [107]	validation-rmse:3.79814
# [108]	validation-rmse:3.79687
# [109]	validation-rmse:3.78891
# [110]	validation-rmse:3.78784
# [111]	validation-rmse:3.78690
# [112]	validation-rmse:3.78449
# [113]	validation-rmse:3.78096
# [114]	validation-rmse:3.78088
# [115]	validation-rmse:3.77858
# [116]	validation-rmse:3.77630
# [117]	validation-rmse:3.77684
# [118]	validation-rmse:3.77529
# [119]	validation-rmse:3.77303
# [120]	validation-rmse:3.77164
# [121]	validation-rmse:3.77149
# [122]	validation-rmse:3.76870
# [123]	validation-rmse:3.76318
# [124]	validation-rmse:3.75769
# [125]	validation-rmse:3.75591
# [126]	validation-rmse:3.75530
# [127]	validation-rmse:3.75573
# [128]	validation-rmse:3.75451
# [129]	validation-rmse:3.74812
# [130]	validation-rmse:3.75000
# [131]	validation-rmse:3.74910
# [132]	validation-rmse:3.74957
# ...
# [90]	validation-rmse:4.04582
# [91]	validation-rmse:4.04025
# [92]	validation-rmse:4.04008
# [93]	validation-rmse:4.04153
# [94]	validation-rmse:4.04495
# [95]	validation-rmse:4.04310
# [96]	validation-rmse:4.04211
# [97]	validation-rmse:4.04049
# [98]	validation-rmse:4.04039
# [99]	validation-rmse:4.04185
# [100]	validation-rmse:4.04358
# [101]	validation-rmse:4.04285
# [102]	validation-rmse:4.04159
# [103]	validation-rmse:4.04088
# [104]	validation-rmse:4.02956
# [105]	validation-rmse:4.02939
# [106]	validation-rmse:4.02960
# [107]	validation-rmse:4.02868
# [108]	validation-rmse:4.02778
# [109]	validation-rmse:4.02696
# [110]	validation-rmse:4.02681
# [111]	validation-rmse:4.02900
# [112]	validation-rmse:4.02510
# [113]	validation-rmse:4.02417
# [114]	validation-rmse:4.02583
# [115]	validation-rmse:4.02427
# [116]	validation-rmse:4.01337
# [117]	validation-rmse:4.01346
# [118]	validation-rmse:4.01307
# [119]	validation-rmse:4.01496
# [120]	validation-rmse:4.01587
# [121]	validation-rmse:4.01277
# [122]	validation-rmse:4.01106
# [123]	validation-rmse:4.00683
# [124]	validation-rmse:4.00613
# [125]	validation-rmse:4.00537
# [126]	validation-rmse:4.00489
# [127]	validation-rmse:4.00476
# [128]	validation-rmse:4.00650
# [129]	validation-rmse:4.00694
# [130]	validation-rmse:4.00598
# [131]	validation-rmse:4.00769
# [132]	validation-rmse:3.99919
# [133]	validation-rmse:3.99857
# [134]	validation-rmse:4.00059
# [135]	validation-rmse:3.99443
# [136]	validation-rmse:3.98998
# [137]	validation-rmse:3.99015
# [138]	validation-rmse:3.98351
# [139]	validation-rmse:3.98124
# [140]	validation-rmse:3.98090
# [141]	validation-rmse:3.98210
# [142]	validation-rmse:3.98049
# [143]	validation-rmse:3.97301
# [144]	validation-rmse:3.97359
# [145]	validation-rmse:3.97350
# [146]	validation-rmse:3.97392
# [147]	validation-rmse:3.97433
# [148]	validation-rmse:3.96818
# [149]	validation-rmse:3.96970
# [150]	validation-rmse:3.96876
# [151]	validation-rmse:3.96965
# [152]	validation-rmse:3.96800
# [153]	validation-rmse:3.96977
# [154]	validation-rmse:3.96199
# [155]	validation-rmse:3.96253
# [156]	validation-rmse:3.96121
# [157]	validation-rmse:3.95737
# [158]	validation-rmse:3.95913
# [159]	validation-rmse:3.95608
# [160]	validation-rmse:3.95486
# [161]	validation-rmse:3.95452
# [162]	validation-rmse:3.95458
# [163]	validation-rmse:3.95624
# [164]	validation-rmse:3.95497
# [165]	validation-rmse:3.95478
# [166]	validation-rmse:3.94937
# [167]	validation-rmse:3.94881
# [168]	validation-rmse:3.95001
# [169]	validation-rmse:3.94334
# [170]	validation-rmse:3.94314
# [171]	validation-rmse:3.93719
# [172]	validation-rmse:3.93704
# [173]	validation-rmse:3.93514
# [174]	validation-rmse:3.93509
# [175]	validation-rmse:3.93550
# [176]	validation-rmse:3.93335
# [177]	validation-rmse:3.93333
# [178]	validation-rmse:3.93412
# [179]	validation-rmse:3.93361
# [180]	validation-rmse:3.93318
# [181]	validation-rmse:3.93414
# [182]	validation-rmse:3.93047
# [183]	validation-rmse:3.93058
# [184]	validation-rmse:3.92892
# [185]	validation-rmse:3.92953
# [186]	validation-rmse:3.93172
# [187]	validation-rmse:3.92760
# [188]	validation-rmse:3.92880
# [189]	validation-rmse:3.92960
# [190]	validation-rmse:3.93043
# [191]	validation-rmse:3.92355
# [192]	validation-rmse:3.92432
# [193]	validation-rmse:3.92443
# [194]	validation-rmse:3.92363
# [195]	validation-rmse:3.92226
# [196]	validation-rmse:3.92274
# [197]	validation-rmse:3.92244
# [198]	validation-rmse:3.92095
# [199]	validation-rmse:3.92026
# 100%|████████████████████████████████████████████████████████████████████████| 10/10 [00:09<00:00,  1.09trial/s, best loss: 3.6881730905210497]

# %% [markdown]
# ## Autolog

# %%
best_params = {
    'max_depth':37,
    'max_leaves': 4,
    'reg_lambda': 0.11373501935624511,
    'reg_alpha': 0.036518723152379994,
    'objective': 'reg:squarederror', 
    'seed':111,
}

mlflow.xgboost.autolog()

booster = xgb.train(
    params=best_params,
    dtrain=train,
    evals=[(val, "validation")],
    num_boost_round=200,
    early_stopping_rounds=50
)
# Out:
# 2024/02/28 12:42:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1c5ae6ec23d8422fbb6fb0ca76a05307', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:7.51286
# [1]	validation-rmse:6.36526
# [2]	validation-rmse:5.62723
# [3]	validation-rmse:5.19291
# [4]	validation-rmse:4.92657
# [5]	validation-rmse:4.76907
# [6]	validation-rmse:4.65459
# [7]	validation-rmse:4.58865
# [8]	validation-rmse:4.54504
# [9]	validation-rmse:4.50514
# [10]	validation-rmse:4.47385
# [11]	validation-rmse:4.45390
# [12]	validation-rmse:4.41816
# [13]	validation-rmse:4.38865
# [14]	validation-rmse:4.37231
# [15]	validation-rmse:4.35497
# [16]	validation-rmse:4.34108
# [17]	validation-rmse:4.33472
# [18]	validation-rmse:4.32534
# [19]	validation-rmse:4.31998
# [20]	validation-rmse:4.31407
# [21]	validation-rmse:4.29691
# [22]	validation-rmse:4.28100
# [23]	validation-rmse:4.27169
# [24]	validation-rmse:4.26724
# [25]	validation-rmse:4.25901
# [26]	validation-rmse:4.24976
# [27]	validation-rmse:4.24290
# [28]	validation-rmse:4.24017
# [29]	validation-rmse:4.23138
# [30]	validation-rmse:4.22622
# [31]	validation-rmse:4.22203
# [32]	validation-rmse:4.22068
# [33]	validation-rmse:4.21702
# [34]	validation-rmse:4.21755
# [35]	validation-rmse:4.22014
# [36]	validation-rmse:4.21509
# [37]	validation-rmse:4.21321
# [38]	validation-rmse:4.21164
# [39]	validation-rmse:4.19927
# [40]	validation-rmse:4.19719
# [41]	validation-rmse:4.18411
# [42]	validation-rmse:4.15728
# [43]	validation-rmse:4.13846
# [44]	validation-rmse:4.13364
# [45]	validation-rmse:4.13606
# [46]	validation-rmse:4.13979
# [47]	validation-rmse:4.14157
# [48]	validation-rmse:4.13918
# [49]	validation-rmse:4.13814
# [50]	validation-rmse:4.13663
# [51]	validation-rmse:4.13307
# [52]	validation-rmse:4.12941
# [53]	validation-rmse:4.13141
# [54]	validation-rmse:4.13348
# [55]	validation-rmse:4.12193
# [56]	validation-rmse:4.10923
# [57]	validation-rmse:4.11013
# [58]	validation-rmse:4.10890
# [59]	validation-rmse:4.10334
# [60]	validation-rmse:4.10577
# [61]	validation-rmse:4.10868
# [62]	validation-rmse:4.10524
# [63]	validation-rmse:4.10235
# [64]	validation-rmse:4.09918
# [65]	validation-rmse:4.09877
# [66]	validation-rmse:4.09785
# [67]	validation-rmse:4.08201
# [68]	validation-rmse:4.08298
# [69]	validation-rmse:4.08094
# [70]	validation-rmse:4.08386
# [71]	validation-rmse:4.07373
# [72]	validation-rmse:4.07584
# [73]	validation-rmse:4.06899
# [74]	validation-rmse:4.06775
# [75]	validation-rmse:4.06818
# [76]	validation-rmse:4.06185
# [77]	validation-rmse:4.06131
# [78]	validation-rmse:4.06171
# [79]	validation-rmse:4.06098
# [80]	validation-rmse:4.06151
# [81]	validation-rmse:4.05451
# [82]	validation-rmse:4.05343
# [83]	validation-rmse:4.05079
# [84]	validation-rmse:4.05457
# [85]	validation-rmse:4.05601
# [86]	validation-rmse:4.06020
# [87]	validation-rmse:4.05444
# [88]	validation-rmse:4.05489
# [89]	validation-rmse:4.04409
# [90]	validation-rmse:4.04582
# [91]	validation-rmse:4.04025
# [92]	validation-rmse:4.04008
# [93]	validation-rmse:4.04153
# [94]	validation-rmse:4.04495
# [95]	validation-rmse:4.04310
# [96]	validation-rmse:4.04211
# [97]	validation-rmse:4.04049
# [98]	validation-rmse:4.04039
# [99]	validation-rmse:4.04185
# [100]	validation-rmse:4.04358
# [101]	validation-rmse:4.04285
# [102]	validation-rmse:4.04159
# [103]	validation-rmse:4.04088
# [104]	validation-rmse:4.02956
# [105]	validation-rmse:4.02939
# [106]	validation-rmse:4.02960
# [107]	validation-rmse:4.02868
# [108]	validation-rmse:4.02778
# [109]	validation-rmse:4.02696
# [110]	validation-rmse:4.02681
# [111]	validation-rmse:4.02900
# [112]	validation-rmse:4.02510
# [113]	validation-rmse:4.02417
# [114]	validation-rmse:4.02583
# [115]	validation-rmse:4.02427
# [116]	validation-rmse:4.01337
# [117]	validation-rmse:4.01346
# [118]	validation-rmse:4.01307
# [119]	validation-rmse:4.01496
# [120]	validation-rmse:4.01587
# [121]	validation-rmse:4.01277
# [122]	validation-rmse:4.01106
# [123]	validation-rmse:4.00683
# [124]	validation-rmse:4.00613
# [125]	validation-rmse:4.00537
# [126]	validation-rmse:4.00489
# [127]	validation-rmse:4.00476
# [128]	validation-rmse:4.00650
# [129]	validation-rmse:4.00694
# [130]	validation-rmse:4.00598
# [131]	validation-rmse:4.00769
# [132]	validation-rmse:3.99919
# [133]	validation-rmse:3.99857
# [134]	validation-rmse:4.00059
# [135]	validation-rmse:3.99443
# [136]	validation-rmse:3.98998
# [137]	validation-rmse:3.99015
# [138]	validation-rmse:3.98351
# [139]	validation-rmse:3.98124
# [140]	validation-rmse:3.98090
# [141]	validation-rmse:3.98210
# [142]	validation-rmse:3.98049
# [143]	validation-rmse:3.97301
# [144]	validation-rmse:3.97359
# [145]	validation-rmse:3.97350
# [146]	validation-rmse:3.97392
# [147]	validation-rmse:3.97433
# [148]	validation-rmse:3.96818
# [149]	validation-rmse:3.96970
# [150]	validation-rmse:3.96876
# [151]	validation-rmse:3.96965
# [152]	validation-rmse:3.96800
# [153]	validation-rmse:3.96977
# [154]	validation-rmse:3.96199
# [155]	validation-rmse:3.96253
# [156]	validation-rmse:3.96121
# [157]	validation-rmse:3.95737
# [158]	validation-rmse:3.95913
# [159]	validation-rmse:3.95608
# [160]	validation-rmse:3.95486
# [161]	validation-rmse:3.95452
# [162]	validation-rmse:3.95458
# [163]	validation-rmse:3.95624
# [164]	validation-rmse:3.95497
# [165]	validation-rmse:3.95478
# [166]	validation-rmse:3.94937
# [167]	validation-rmse:3.94881
# [168]	validation-rmse:3.95001
# [169]	validation-rmse:3.94334
# [170]	validation-rmse:3.94314
# [171]	validation-rmse:3.93719
# [172]	validation-rmse:3.93704
# [173]	validation-rmse:3.93514
# [174]	validation-rmse:3.93509
# [175]	validation-rmse:3.93550
# [176]	validation-rmse:3.93335
# [177]	validation-rmse:3.93333
# [178]	validation-rmse:3.93412
# [179]	validation-rmse:3.93361
# [180]	validation-rmse:3.93318
# [181]	validation-rmse:3.93414
# [182]	validation-rmse:3.93047
# [183]	validation-rmse:3.93058
# [184]	validation-rmse:3.92892
# [185]	validation-rmse:3.92953
# [186]	validation-rmse:3.93172
# [187]	validation-rmse:3.92760
# [188]	validation-rmse:3.92880
# [189]	validation-rmse:3.92960
# [190]	validation-rmse:3.93043
# [191]	validation-rmse:3.92355
# [192]	validation-rmse:3.92432
# [193]	validation-rmse:3.92443
# [194]	validation-rmse:3.92363
# [195]	validation-rmse:3.92226
# [196]	validation-rmse:3.92274
# [197]	validation-rmse:3.92244
# [198]	validation-rmse:3.92095
# [199]	validation-rmse:3.92026
# 2024/02/28 12:42:36 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/02/28 12:42:36 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/2024_hs_iml/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [12:42:36] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."

# %% [markdown]
# ## Load Model

# %%
logged_model_id = 'runs:/1c5ae6ec23d8422fbb6fb0ca76a05307/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model_id)

# %%
type(loaded_model)
# Out:
# mlflow.pyfunc.PyFuncModel

# %%
y_val_pred_load_model =loaded_model.predict(X_val)

# %%
rmse = mean_squared_error(y_val, y_val_pred_load_model, squared=False)

# %%
rmse
# Out:
# 3.9202611413076642

# %% [markdown]
# ## Mlflow Client

# %%
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType

# %%
MLFLOW_URI = "sqlite:///mlflow.db"

# %%
client = MlflowClient(MLFLOW_URI)

# %%
client.create_experiment(name = "New experimnet created from the python API")
# Out:
# '2'

# %%
runs = client.search_runs(
    experiment_ids='1',
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=10
)

# %%
runs[0].data.metrics["validation-rmse"]
# Out:
# 3.9202611363663564

# %%
for run in runs:
    print(f"run_id={run.info.run_id}, rmse={run.data.metrics}")
# Out:
# run_id=1c5ae6ec23d8422fbb6fb0ca76a05307, rmse={'validation-rmse': 3.9202611363663564, 'stopped_iteration': 199.0, 'best_iteration': 199.0}
# run_id=e5f48f4505e54acba7969053f8bdcddb, rmse={'rmse': 3.9202611413076642}
# run_id=f11a6decf30a4f81a1716e9705c92984, rmse={'rmse': 4.086666325205767}
# run_id=724183a0fa9045f3990723687a72cdf7, rmse={'rmse': 3.8736398834404864}
# run_id=c0162ccb9bc9483a892c5a5437b677a6, rmse={'rmse': 3.8796079918639896}
# run_id=5e9324c9b56244abbfd49fbc3bb3e6aa, rmse={'rmse': 4.080169670113804}
# run_id=0bebd74ae0d94d5cb7b470d09ed43dc8, rmse={'rmse': 3.7728073068070977}
# run_id=8e1e5c73e11b43fd965a76c90eda794c, rmse={'rmse': 3.9440387616463783}
# run_id=167ba9bbcb6a49f9a18bb05de9d207d5, rmse={'rmse': 3.8736311363642715}
# run_id=18d2b51a6bff4f85b2a206c98973cdbf, rmse={'rmse': 3.6881730905210497}
